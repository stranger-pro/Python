# %%
import numpy as np

arr = np.array([2,3,2,0,5], dtype=bool)

print(arr)

print(type(arr))

# %%
import numpy as np

arr = np.array([2,3,2,0,5], dtype=float)

print(arr)

print(type(arr))

# %%
import numpy as np

arr = np.array([2,3,2,0,5], dtype=str)

print(arr)

print(type(arr))

# %%
import numpy as np

arr = np.array([2,3,2,0,5], dtype=complex)

print(arr)

print(type(arr))
