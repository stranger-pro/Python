# %%
print("hellow world")
# Out:
# hellow world

# %%
import numpy as np

arr = np.array([1,2,3,4,5])

print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np

arr  = np.arange(1,6)**2

print(arr)
# Out:
# [ 1  4  9 16 25]

# %%
import numpy as np 

arr = np.array([[1,2,3,4,5,6],[2,8,4,6,7,3]])

print(arr)

print("Dimension Of Array : ",arr.ndim)
# Out:
# [[1 2 3 4 5 6]
#  [2 8 4 6 7 3]]
# Dimension Of Array :  2
