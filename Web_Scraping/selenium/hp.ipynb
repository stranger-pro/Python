# %%
import pandas as pd

# %%
hp = pd.read_csv('hp.csv')

# %%
hp
# Out:
#                                         Name  Price  Rating  \
# 0        HP Victus 15-fb3012AX Gaming Laptop  66240    72.0
# 1         HP Victus 16-r1705TX Gaming Laptop  66240    72.0
# 2                          HP 245 G10 Laptop  66240    55.0
# 3                      HP 15-fr0028TU Laptop  66240    53.0
# 4        HP Victus 15-fb3004AX Gaming Laptop  66240    70.0
# ..                                       ...    ...     ...
# 975       HP Spectre x360 13-ef0057TU Laptop  66240    66.0
# 976        HP Spectre x360 16-f1009TX Laptop  66240    74.0
# 977  HP Spectre x360 13-ef0052TU OLED Laptop  66240    63.0
# 978                 HP 250 G8 64Q91PA Laptop  66240     NaN
# 979          HP Envy x360 13-bf0059TU Laptop  66240    63.0
#
#                           Proccesor                 Core  Thread RAM(GB)  \
# 0        8th Gen AMD Ryzen 5 8645HS            Hexa Core    12.0      16
# 1    14th Gen Intel Core i5 14450HX   10 Cores (6P + 4E)    16.0      16
# ...
