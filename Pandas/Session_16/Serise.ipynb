# %%
import numpy as np
import pandas as pd

# %%
country = ['india','Aus','usa','itly','france']

pd.Series(country)

# %%
marks = [23,34,55,7,65,4,5,9,3,28,98,74,23]

pd.Series(marks)

# %%
marks = [92,88,63,54]
sub = ['Hindi','English','Math','History']

pd.Series(marks,index=sub,name="bhai sahb")

# %%
mark = {
    'maths' : 23,
    'english' : 26,
    'hindi' :  54,
}

marks = pd.Series(mark,name='nice')

# %%
marks.size
# Out:
# 3

# %%
print(marks.name)
# Out:
# nice

# %%
marks.is_unique  #All elements are unique
# Out:
# True

# %%
marks.index
# Out:
# Index(['maths', 'english', 'hindi'], dtype='object')

# %%
marks.values
# Out:
# array([23, 26, 54])
