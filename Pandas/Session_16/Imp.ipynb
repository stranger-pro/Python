# %%
import pandas as pd

vk1 = pd.read_csv('kohli_ipl.csv',index_col='match_no')

vk = vk1.squeeze()

# %%
new = vk.head().copy() #create copy not view

new[2] = 34 # not change in original

new

# %%
vk.duplicated().sum() # count duplicate num
# Out:
# np.int64(137)

# %%
vk.drop_duplicates() # remove duplicate

# %%
vk.apply(lambda x: 'good_score' if x > vk.median() else ' bad ')

# %%
vk[vk.isin([2,33])]

# %%
vk[vk.isin([100,50])]
