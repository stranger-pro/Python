# %%
import pandas as pd

serise = pd.read_csv('subs.csv')

serise1 = serise.squeeze()

print(type(serise1))
print(serise1)

# %%
vk = pd.read_csv('kohli_ipl.csv',index_col='match_no')

vk1 = vk.squeeze()

print(type(vk1))
print(vk)

# %%
bm = pd.read_csv('bollywood.csv',index_col='movie')
bm1 = bm.squeeze()
bm1

# %%
bm1.sample()

# %%
bm1.apply(lambda x: x.split(' ')[0]) #help to custom serise
# Out:
# movie
# Uri: The Surgical Strike                  Vicky
# Battalion 609                             Vicky
# The Accidental Prime Minister (film)     Anupam
# Why Cheat India                          Emraan
# Evening Shadows                            Mona
#                                          ...
# Hum Tumhare Hain Sanam                     Shah
# Aankhen (2002 film)                     Amitabh
# Saathiya (film)                           Vivek
# Company (film)                             Ajay
# Awara Paagal Deewana                     Akshay
# Name: lead, Length: 1500, dtype: object
