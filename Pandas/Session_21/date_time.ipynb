# %%
import pandas as pd

# %%
pd.Timestamp('2022')
# Out:
# Timestamp('2022-01-01 00:00:00')

# %%
pd.Timestamp('2022/2/2')
# Out:
# Timestamp('2022-02-02 00:00:00')

# %%
pd.Timestamp('5 jan 2025')
# Out:
# Timestamp('2025-01-05 00:00:00')

# %%
d_idx = pd.DatetimeIndex([pd.Timestamp(2022,5,3),pd.Timestamp(2011,6,2),pd.Timestamp(2033,2,4)]) #convert into seerise
pd.Series([1,2,3],index=d_idx)
# Out:
# 2022-05-03    1
# 2011-06-02    2
# 2033-02-04    3
# dtype: int64

# %%
date = pd.date_range(start='2022/2/3',end='2022/3/5',freq='D')
date
# Out:
# DatetimeIndex(['2022-02-03', '2022-02-04', '2022-02-05', '2022-02-06',
#                '2022-02-07', '2022-02-08', '2022-02-09', '2022-02-10',
#                '2022-02-11', '2022-02-12', '2022-02-13', '2022-02-14',
#                '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18',
#                '2022-02-19', '2022-02-20', '2022-02-21', '2022-02-22',
#                '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26',
#                '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02',
#                '2022-03-03', '2022-03-04', '2022-03-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2022/2/3',end='2022/3/5',freq='2D')
# Out:
# DatetimeIndex(['2022-02-03', '2022-02-05', '2022-02-07', '2022-02-09',
#                '2022-02-11', '2022-02-13', '2022-02-15', '2022-02-17',
#                '2022-02-19', '2022-02-21', '2022-02-23', '2022-02-25',
#                '2022-02-27', '2022-03-01', '2022-03-03', '2022-03-05'],
#               dtype='datetime64[ns]', freq='2D')

# %%
pd.date_range(start='2022/2/3',end='2022/3/5',freq='B')
# Out:
# DatetimeIndex(['2022-02-03', '2022-02-04', '2022-02-07', '2022-02-08',
#                '2022-02-09', '2022-02-10', '2022-02-11', '2022-02-14',
#                '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18',
#                '2022-02-21', '2022-02-22', '2022-02-23', '2022-02-24',
#                '2022-02-25', '2022-02-28', '2022-03-01', '2022-03-02',
#                '2022-03-03', '2022-03-04'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start='2022/2/3',end='2022/3/5',freq='W')
# Out:
# DatetimeIndex(['2022-02-06', '2022-02-13', '2022-02-20', '2022-02-27'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start='2022/2/3',periods=25,freq='D') #no end
# Out:
# DatetimeIndex(['2022-02-03', '2022-02-04', '2022-02-05', '2022-02-06',
#                '2022-02-07', '2022-02-08', '2022-02-09', '2022-02-10',
#                '2022-02-11', '2022-02-12', '2022-02-13', '2022-02-14',
#                '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18',
#                '2022-02-19', '2022-02-20', '2022-02-21', '2022-02-22',
#                '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26',
#                '2022-02-27'],
#               dtype='datetime64[ns]', freq='D')
